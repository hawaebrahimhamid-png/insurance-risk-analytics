# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\admin\\Desktop\\10-academy\\insurance-risk-analytics\\notebooks'

# %%
import os

os.listdir("../data")
# Out:
# ['insurance_data.csv']

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\admin\Desktop\10-academy\insurance-risk-analytics\notebooks

# %%
import os
os.chdir(r"C:\Users\admin\Desktop\10-academy\insurance-risk-analytics")
print(os.getcwd())
# Out:
# C:\Users\admin\Desktop\10-academy\insurance-risk-analytics

# %%
import pandas as pd

df = pd.read_csv("data/insurance_data.csv")

# %%
import os
print(os.listdir("data"))
# Out:
# ['insurance_data.csv', 'insurance_data_cleaned.csv']

# %%
import pandas as pd

df = pd.read_csv("data/insurance_data.csv")

df = df.drop_duplicates()

df.to_csv("data/insurance_data_cleaned.csv", index=False)
